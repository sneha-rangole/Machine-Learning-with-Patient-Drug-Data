# %% [markdown]
# # n8n
# **The Smart Assistant That Automates Your Work**

# %% [markdown]
# ## 1. What Is n8n? (Simple Explanation)
#
# Think of **n8n** like a smart assistant who watches for specific events and automatically does tasks for you.
#
# For example: When someone fills out a Google Form, n8n can automatically:
# - Send them a confirmation email
# - Add their info to a spreadsheet
# - Notify your team on Slack
# - Create a task in your project manager
#
# **All without you lifting a finger.**
#
# It's called a **workflow automation tool** but basically, it's a way to connect different apps and make them work together automatically.
#
# ### Real-Life Analogy
#
# Imagine you have a home security system:
# - **Trigger**: Motion sensor detects movement
# - **Action 1**: Lights turn on automatically
# - **Action 2**: Camera starts recording
# - **Action 3**: You get a phone notification
#
# n8n does the same thing, but for your digital apps instead of your home.
#
# ---

# %% [markdown]
# ## 2. How n8n Compares to Zapier, Make, and Others
#
# All these tools do the same basic thing **connect apps and automate workflows**. But they have key differences:
#
# | Feature | n8n | Zapier | Make (Integretely) |
# |---------|-----|--------|-------------------|
# | **Pricing** | Free (self-hosted) or paid (cloud) | Paid plans only | Paid plans only |
# | **Customization** | Full code access | Limited | Medium |
# | **Hosting** | Self-hosted OR cloud | Cloud only | Cloud only |
# | **Technical Level** | Medium (more control) | Beginner-friendly | Beginner-friendly |
# | **Best For** | Developers, tech-savvy users | Non-technical users | Visual workflow lovers |
#
# ### Simple Breakdown:
#
# **Zapier** = The easiest, but you're renting someone else's car. Limited customization.
#
# **Make** = Like Zapier but with a prettier interface and more visual controls.
#
# **n8n** = You own the car. More setup, but total freedom and no monthly limits if self-hosted.
#
# ---

# %% [markdown]
# ## 3. Self-Hosted vs Cloud - What's the Difference?
#
# ### **Cloud Version** (n8n Cloud)
#
# You use n8n through their website - no setup needed.
#
# **Pros:**
# - No technical setup required
# - Works immediately
# - They handle updates and maintenance
# - Access from anywhere with internet
#
# **Cons:**
# - Monthly subscription cost
# - Limited executions on lower plans
# - Your data lives on their servers
#
# **Think of it like:** Renting an apartment. Easy, no maintenance, but you pay monthly rent.
#
# ### **Self-Hosted Version**
#
# You install n8n on your own server (like a computer that runs 24/7).
#
# **Pros:**
# - **100% free forever** (no execution limits)
# - Your data stays with you (full privacy)
# - Full control over everything
# - No monthly fees
#
# **Cons:**
# - Requires technical setup (Docker, server knowledge)
# - You handle updates and maintenance
# - Need a server (Raspberry Pi, cloud VM, etc.)
#
# **Think of it like:** Owning a house. More work upfront, but it's yours forever.
#
# ---

# %% [markdown]
# ## 4. When Should You Use n8n?
#
# ### **Use n8n if you:**
#
# 1. **Want to save money long-term** — Self-hosting is free
# 2. **Care about data privacy** — Keep everything on your own server
# 3. **Have technical skills** — Comfortable with Docker, APIs, or coding
# 4. **Need unlimited executions** — Self-hosted has no limits
# 5. **Want full customization** — Access to code and advanced features
#
# ### **Don't use n8n if you:**
#
# 1. **Need something RIGHT NOW** — Zapier is faster to set up
# 2. **Have zero technical knowledge** — Zapier/Make are more beginner-friendly
# 3. **Don't want to manage servers** — Cloud versions are easier
# 4. **Have simple, basic needs** — Zapier's free tier might be enough
#
# ---

# %% [markdown]
# ## 5. Real-Life Example - When n8n Shines
#
# ### Scenario: You Run a Small Online Course
#
# Every time someone buys your course:
#
# 1. **Trigger**: Payment received via Stripe
# 2. **Action 1**: Send welcome email with course link
# 3. **Action 2**: Add student to Google Sheet
# 4. **Action 3**: Create account in your course platform
# 5. **Action 4**: Send Slack notification to your team
# 6. **Action 5**: Add student to email marketing list
#
# **With Zapier:** You'd pay $20-$50/month if you have hundreds of students.
#
# **With n8n (self-hosted):** Run this workflow 10,000 times a month — **$0 cost.**
#
# ---

# %% [markdown]
# ## 6. Common Mistakes Beginners Make
#
# ### ❌ **Mistake 1: Starting with self-hosted without Docker knowledge**
#
# If you don't know what Docker is, start with n8n Cloud first. Learn the tool, then self-host later.
#
# ### ❌ **Mistake 2: Building overly complex workflows immediately**
#
# Start simple. One trigger → One action. Then gradually add complexity.
#
# ### ❌ **Mistake 3: Not testing workflows before going live**
#
# Always test with fake data first. Don't accidentally send 100 emails to real customers.
#
# ### ❌ **Mistake 4: Ignoring error handling**
#
# What happens if a step fails? Always add fallback actions (like logging errors to a spreadsheet).
#
# ---

# %% [markdown]
# # n8n Core Concepts
# **Understanding the Building Blocks**

# %% [markdown]
# Before you build automation workflows, you need to understand the **building blocks** n8n uses.
#
# Think of n8n like building with **LEGO blocks**:
# - Each piece has a specific purpose
# - You connect them together
# - The final creation does something useful
#
# Let's break down each piece so you can build anything you want.
#
# ---

# %% [markdown]
# ## 1. Workflows - Your Automation Blueprint
#
# ### What Is a Workflow?
#
# A **workflow** is the entire automation process from start to finish.
#
# ### Real-Life Analogy
#
# Think of making breakfast:
# 1. **Start**: Alarm goes off (trigger)
# 2. **Step 1**: Make coffee
# 3. **Step 2**: Cook eggs
# 4. **Step 3**: Toast bread
# 5. **End**: Breakfast is ready
#
# In n8n, a workflow is the entire breakfast-making process. Each step is a **node**.
#
# ### Example Workflow
#
# **"New Customer Onboarding"**
# - Trigger: New sale in Shopify
# - Action 1: Send welcome email
# - Action 2: Add to Google Sheet
# - Action 3: Create account in course platform
# - Action 4: Notify team on Slack
#
# That entire sequence = **one workflow**.
#
# ---

# %% [markdown]
# ## 2. Nodes - The Individual Steps
#
# ### What Is a Node?
#
# A **node** is a single step or action in your workflow.
#
# Each node does **one specific thing**:
# - Send an email
# - Read from a database
# - Transform data
# - Make an HTTP request
#
# ### Real-Life Analogy
#
# Imagine an assembly line in a factory:
#
# **Making a car:**
# - Node 1: Add chassis
# - Node 2: Install engine
# - Node 3: Attach wheels
# - Node 4: Paint the car
#
# Each station = **one node**. Together they make the complete car = **workflow**.
#
# ### Types of Nodes
#
# | Node Type | What It Does | Example |
# |-----------|--------------|---------|
# | **Trigger Node** | Starts the workflow | "When form is submitted" |
# | **Action Node** | Does something | "Send email", "Save to database" |
# | **Logic Node** | Makes decisions | "IF this, THEN that" |
# | **Data Node** | Transforms data | "Change date format", "Merge lists" |
#
# ---

# %% [markdown]
# ## 3. Triggers - What Starts Your Workflow
#
# ### What Is a Trigger?
#
# A **trigger** is the event that **kicks off** your entire workflow.
#
# Without a trigger, nothing happens. It's the ignition key.
#
# ### Real-Life Analogy
#
# **Starting a car:**
# - Trigger: You turn the key
# - Result: Engine starts, everything else follows
#
# **Smart home:**
# - Trigger: You say "Hey Google, good morning"
# - Result: Lights turn on, coffee maker starts, news plays
#
# ### Common Trigger Types
#
# **1. Webhook Trigger** — When someone sends data to a URL
# ```
# Example: Stripe sends payment confirmation → Workflow starts
# ```
# **2. Schedule Trigger** — Runs at specific times
# ```
# Example: Every Monday at 9 AM → Send weekly report
# ```
# **3. App Trigger** — When something happens in an app
# ```
# Example: New email arrives → Workflow starts
# ```
# **4. Manual Trigger** — You click a button to start
# ```
# Example: You press "Run" → Workflow starts
# ```
# ### Important Rule
#
# **One workflow = One trigger** (usually)
#
# You can't have "when form submits OR every Monday". Those would be two separate workflows.
#
# ---

# %% [markdown]
# ## 4. Actions - What Your Workflow Does
#
# ### What Is an Action?
#
# An **action** is any node that **does something** after the trigger fires.
#
# ### Real-Life Analogy
#
# Think of a movie director:
# - **Trigger**: Director yells "Action!"
# - **Actions**: Actors perform their scenes
#
# In n8n:
# - **Trigger**: New customer signs up
# - **Actions**: Send email → Add to database → Notify team
#
# ### Common Actions
#
# | Action Type | What It Does | Example |
# |-------------|--------------|---------|
# | **Send** | Sends something | Send email, Slack message, SMS |
# | **Create** | Makes something new | Create row in database, new file |
# | **Update** | Changes existing data | Update spreadsheet, edit record |
# | **Read** | Gets information | Fetch customer data, read file |
# | **Delete** | Removes something | Delete old files, remove user |
#
# ### Example Chain of Actions
#
# **Workflow: "New Blog Post Published"**
#
# 1. Trigger: New post in WordPress
# 2. Action 1: Create social media post
# 3. Action 2: Send to email subscribers
# 4. Action 3: Add to Google Analytics
# 5. Action 4: Notify marketing team
#
# Each action is a separate **node** in the workflow.
#
# ---

# %% [markdown]
# ## 5. Credentials - Your Login Keys
#
# ### What Are Credentials?
#
# **Credentials** are the login information that let n8n access your apps on your behalf.
#
# Think of them as **permission slips**.
#
# ### Real-Life Analogy
#
# Imagine you hire an assistant:
# - You give them your **office key** (credentials)
# - Now they can enter your office (app)
# - They do tasks for you (automation)
#
# Without the key, they can't get in.
#
# ### How Credentials Work
#
# When you add a Gmail node, n8n asks:
# ```
# "Which Gmail account should I use?"
# ```
#
# You provide:
# - Your email address
# - Authorization (via OAuth)
# - n8n stores this securely
#
# Now n8n can send emails **as you** automatically.
#
# ### Security Note
#
# Credentials are **encrypted** and stored securely. If self-hosting, they're stored on your own server.
#
# ### Example
#
# **Connecting to Slack:**
# 1. Add Slack node to workflow
# 2. Click "Create New Credential"
# 3. Authorize n8n to access your Slack
# 4. Choose which workspace/channel
# 5. Save → Now n8n can post to Slack for you
#
# ---

# %% [markdown]
# ## 6. Executions - Each Time Your Workflow Runs
#
# ### What Is an Execution?
#
# An **execution** is **one complete run** of your workflow from start to finish.
#
# ### Real-Life Analogy
#
# Think of running a marathon:
# - **Workflow**: The marathon route (doesn't change)
# - **Execution**: You actually running the race (one specific run)
#
# You can run the same marathon route 100 times = 100 executions.
#
# ### Example
#
# **Workflow: "Send Daily Report"**
#
# If this runs every day for a week:
# - Monday's run = 1 execution
# - Tuesday's run = 1 execution
# - ...
# - Sunday's run = 1 execution
#
# **Total: 7 executions** of the same workflow.
#
# ### Why Executions Matter
#
# **Pricing on n8n Cloud:**
# - Plans limit **executions per month**
# - Example: 5,000 executions/month on Starter plan
# - If you exceed, you pay extra or upgrade
#
# **Self-hosted:**
# - Unlimited executions (it's free!)
#
# ### Viewing Executions
#
# n8n logs every execution:
# - Success ✅ or Failed ❌
# - What data passed through
# - How long it took
# - Any errors that occurred
#
# This helps you **debug** when things go wrong.
#
# ---

# %% [markdown]
# ## 7. Data Flow - How Information Moves
#
# ### What Is Data Flow?
#
# **Data flow** is how information **moves from one node to the next** in your workflow.
#
# ### Real-Life Analogy
#
# Imagine a factory assembly line:
#
# ```
# Raw Materials → Machine 1 → Machine 2 → Machine 3 → Finished Product
# ```
#
# Each machine receives something, processes it, and passes it forward.
#
# In n8n:
# ```
# Trigger → Node 1 → Node 2 → Node 3 → End
# ```
#
# ### How It Works
#
# **Example: "New Form Submission"**
#
# ```
# 1. Trigger receives form data:
#    - Name: "Sarah"
#    - Email: "sarah@email.com"
#    - Message: "Hello!"
#
# 2. Node 1 (Send Email) receives this data
#    - Uses email field → sarah@email.com
#    - Sends confirmation email
#
# 3. Node 2 (Google Sheets) receives same data
#    - Creates new row with all fields
#
# 4. Node 3 (Slack) receives same data
#    - Posts: "New submission from Sarah"
# ```
#
# Each node gets the **output from the previous node**.
#
# ### Key Concept
#
# Data flows like a river:
# - Starts at the trigger
# - Flows through each connected node
# - Each node can use or modify the data
# - Final node receives everything that came before
#
# ---

# %% [markdown]
# ## 8. JSON Structure - How Data Is Organized
#
# ### What Is JSON?
#
# **JSON** (JavaScript Object Notation) is how n8n stores and passes data between nodes.
#
# Don't worry — you don't need to be a programmer. Just understand the basics.
#
# ### Real-Life Analogy
#
# Think of JSON like a **labeled box**:
#
# ```
# Box Label: Customer
# ├── Name: "John"
# ├── Age: 30
# ├── Email: "john@email.com"
# └── Address:
#     ├── Street: "123 Main St"
#     ├── City: "Boston"
#     └── Zip: "02101"
# ```
#
# ### Actual JSON Format
#
# ```json
# {
#   "name": "John",
#   "age": 30,
#   "email": "john@email.com",
#   "address": {
#     "street": "123 Main St",
#     "city": "Boston",
#     "zip": "02101"
#   }
# }
# ```
#
# ### Why This Matters in n8n
#
# When data flows between nodes, it looks like this JSON structure.
#
# **Example:**
#
# Your form submission comes in as:
# ```json
# {
#   "firstName": "Sarah",
#   "lastName": "Smith",
#   "email": "sarah@email.com",
#   "message": "I need help"
# }
# ```
#
# To access Sarah's email in the next node, you reference:
# ```
# {{ $json.email }}
# ```
# This grabs the value `sarah@email.com`.
#
# ### Don't Panic!
# n8n has a visual interface. You usually **click to select** fields instead of typing JSON manually.
#
# ---

# %% [markdown]
# ## 9. Items - Individual Pieces of Data
#
# ### What Are Items?
#
# An **item** is one individual record or piece of data flowing through your workflow.
#
# ### Real-Life Analogy
#
# Imagine a cookie factory:
#
# **One batch makes 100 cookies:**
# - Each cookie = **one item**
# - The batch = **all items together**
#
# In n8n:
# - If 10 form submissions come in → 10 items
# - Each submission is processed separately
#
# ### Example
#
# **Scenario: Reading from a Google Sheet with 5 rows**
#
# ```
# Row 1: { name: "Alice", age: 25 }  → Item 1
# Row 2: { name: "Bob", age: 30 }    → Item 2
# Row 3: { name: "Carol", age: 28 }  → Item 3
# Row 4: { name: "Dave", age: 35 }   → Item 4
# Row 5: { name: "Eve", age: 22 }    → Item 5
# ```
#
# n8n processes all 5 items through the workflow.
#
# ### Why This Matters
#
# Some nodes process **one item at a time**, others process **all items together**.
#
# **Example:**
#
# **Send Email node:**
# - Processes each item separately
# - Sends 5 separate emails (one for Alice, one for Bob, etc.)
#
# **Aggregate node:**
# - Combines all items into one
# - Creates a single report with all 5 names
#
# ---

# %% [markdown]
# ## 10. Expressions - Dynamic Values
#
# ### What Are Expressions?
#
# **Expressions** let you insert **dynamic data** into your workflow instead of hard-coded text.
#
# ### Real-Life Analogy
#
# **Static email (boring):**
# ```
# Subject: Welcome!
# Body: Hello. Thanks for signing up.
# ```
#
# **Dynamic email (personalized):**
# ```
# Subject: Welcome, Sarah!
# Body: Hello Sarah. Thanks for signing up on February 24th.
# ```
#
# The name and date **change based on the data**.
#
# ### How Expressions Work in n8n
#
# You wrap dynamic values in **double curly braces**: `{{ }}`
#
# **Example:**
#
# Form submission has:
# ```json
# {
#   "name": "Sarah",
#   "email": "sarah@email.com"
# }
# ```
#
# In your email node:
# ```
# Subject: Welcome, {{ $json.name }}!
# Body: We'll send updates to {{ $json.email }}
# ```
# **Result:**
# ```
# Subject: Welcome, Sarah!
# Body: We'll send updates to sarah@email.com
# ```
#
# ### Common Expressions
#
# | Expression | What It Does | Example Output |
# |------------|--------------|----------------|
# | `{{ $json.fieldName }}` | Gets value from current item | "Sarah" |
# | `{{ $now }}` | Current date/time | "2025-02-24" |
# | `{{ $json.email.toLowerCase() }}` | Transforms data | "sarah@email.com" |
# | `{{ $json.firstName + " " + $json.lastName }}` | Combines fields | "Sarah Smith" |
#
# ### Pro Tip
#
# n8n has a **visual selector**. You can click on fields instead of typing expressions manually.
#
# ---

# %% [markdown]
# ## 11. Parameters - Settings for Each Node
#
# ### What Are Parameters?
#
# **Parameters** are the settings you configure for each node to tell it **what to do** and **how to do it**.
#
# ### Real-Life Analogy
#
# Ordering coffee:
# - **What**: "I want a latte" (action)
# - **Parameters**:
#   - Size: Large
#   - Milk: Oat milk
#   - Temperature: Extra hot
#   - Sugar: 2 packets
#
# In n8n, parameters are the customization options for each node.
#
# ### Example: Gmail Send Node
#
# **Parameters you set:**
# - **To**: `{{ $json.email }}` (who receives it)
# - **Subject**: "Welcome to our course!"
# - **Body**: Your email message
# - **Attachments**: Optional file
# - **CC/BCC**: Optional additional recipients
#
# ### Types of Parameters
#
# **1. Required Parameters** (must fill)
# - Example: Email recipient address
#
# **2. Optional Parameters** (nice to have)
# - Example: CC, BCC, attachments
#
# **3. Advanced Parameters** (for power users)
# - Example: Custom headers, reply-to address
#
# ### Visual Example
#
# When you add a Slack node, you see:
# ```
# ┌─────────────────────────────┐
# │ Slack Node                  │
# ├─────────────────────────────┤
# │ Credential: [Select]        │ ← Required
# │ Channel: #general           │ ← Required
# │ Message: Hello!             │ ← Required
# │ Username: Bot Name          │ ← Optional
# │ Icon: :robot_face:          │ ← Optional
# └─────────────────────────────┘
# ```
#
# Each field = one parameter.
#
# ---

# %% [markdown]
# ## 12. How Everything Works Together
#
# ### The Complete Picture
#
# Let's see how all these concepts connect in one workflow:
#
# ### Example: "New Customer Onboarding"
#
# ```
# ┌─────────────────────────────────────────────────┐
# │ TRIGGER: Webhook                                │
# │ (Receives new customer data when they sign up)  │
# │                                                 │
# │ Items: 1 customer                               │
# │ JSON: { name: "Sarah", email: "sarah@email..." }│
# └─────────────────────────────────────────────────┘
#                     ↓ (data flows down)
# ┌─────────────────────────────────────────────────┐
# │ NODE 1: Gmail                                   │
# │ Action: Send email                              │
# │ Parameters:                                     │
# │   - To: {{ $json.email }}                       │ ← Expression
# │   - Subject: "Welcome {{ $json.name }}!"        │ ← Expression
# │ Credentials: Your Gmail account                 │
# └─────────────────────────────────────────────────┘
#                     ↓
# ┌─────────────────────────────────────────────────┐
# │ NODE 2: Google Sheets                           │
# │ Action: Append row                              │
# │ Parameters:                                     │
# │   - Sheet: "Customers"                          │
# │   - Name: {{ $json.name }}                      │
# │   - Email: {{ $json.email }}                    │
# │ Credentials: Your Google account                │
# └─────────────────────────────────────────────────┘
#                     ↓
# ┌─────────────────────────────────────────────────┐
# │ NODE 3: Slack                                   │
# │ Action: Send message                            │
# │ Parameters:                                     │
# │   - Channel: #sales                             │
# │   - Message: "New customer: {{ $json.name }}"   │
# │ Credentials: Your Slack workspace               │
# └─────────────────────────────────────────────────┘
#
# EXECUTION: One complete run = 1 execution
# ```
# ---

# %% [markdown]
# ## 13. Common Mistakes & How to Avoid Them
#
# ### ❌ Mistake 1: Forgetting to Connect Credentials
#
# **Problem:** Node says "No credentials configured"
#
# **Solution:** Always set up credentials before testing your workflow.
#
# ---
#
# ### ❌ Mistake 2: Not Understanding Data Flow
#
# **Problem:** Node doesn't have the data you expect
#
# **Why:** Previous node didn't pass the right information
#
# **Solution:** Click "Execute Node" to see what data each node receives.
#
# ---
#
# ### ❌ Mistake 3: Using Wrong Expression Syntax
#
# **Problem:** `{{ json.email }}` doesn't work
#
# **Why:** Missing the `$` symbol
#
# **Solution:** Always use `{{ $json.email }}` (with the dollar sign)
#
# ---
#
# ### ❌ Mistake 4: Too Many Items Overwhelming a Node
#
# **Problem:** Workflow tries to send 1,000 emails at once
#
# **Why:** You didn't add a loop or batch process
#
# **Solution:** Use the "Split In Batches" node to process items in groups.

# %% [markdown]
# # n8n UI Walkthrough
# **Your Automation Control Center**

# %% [markdown]
# ## 1. What Is the n8n Interface?
#
# The n8n interface is where you **build, test, and manage** your automation workflows.
#
# Think of it like a **control center** where you have different screens and tools to create your automations.
#
# ### Real-Life Analogy
#
# Imagine you're a music producer in a recording studio:
# - **Canvas**: The main mixing board where you arrange tracks
# - **Node Editor**: Settings panel for each individual instrument
# - **Execution Log**: Recording history of all your sessions
# - **Testing**: Preview button to hear how it sounds
# - **Debug Panel**: Diagnostic screen to fix audio issues
#
# Each tool serves a specific purpose. Let's explore them one by one.
#
# ---

# %% [markdown]
# ## 2. The Canvas - Your Workflow Workspace
#
# ### What Is the Canvas?
#
# The **canvas** is the main workspace where you visually **build your workflow** by dragging and connecting nodes.
#
# It's the big empty space when you first open n8n.
#
# ### Real-Life Analogy
#
# Think of it like a blank **art canvas** or **whiteboard**:
# - You start with empty space
# - You add elements (nodes)
# - You connect them with lines (data flow)
# - You arrange them however makes sense to you
#
# ### What You See on the Canvas
#
# ```
# ┌──────────────────────────────────────────────────────┐
# │  n8n                                    [▶ Execute]  │
# ├──────────────────────────────────────────────────────┤
# │                                                      │
# │                                                      │
# │         ┌─────────────┐                              │
# │         │   Manual    │                              │
# │         │   Trigger   │                              │
# │         └──────┬──────┘                              │
# │                │                                     │
# │                ↓                                     │
# │         ┌─────────────┐                              │
# │         │   Gmail     │                              │
# │         │ Send Email  │                              │
# │         └──────┬──────┘                              │
# │                │                                     │
# │                ↓                                     │
# │         ┌─────────────┐                              │
# │         │   Slack     │                              │
# │         │Send Message │                              │
# │         └─────────────┘                              │
# │                                                      │
# │                                                      │
# └──────────────────────────────────────────────────────┘
# ```
#
# ### Key Features of the Canvas
#
# **1. Zoom Controls**
# - Zoom in/out to see details or big picture
# - Use mouse wheel or zoom buttons
#
# **2. Drag to Move**
# - Click empty space and drag to pan around
# - Helpful when workflows get big
#
# **3. Node Connection Lines**
# - Lines show how data flows between nodes
# - Click and drag from one node to another to connect
#
# **4. Add Node Button (+)**
# - Click the `+` button to add a new node
# - Search for the node you want
#
# ### How to Use the Canvas
#
# **Step 1: Add Your First Node**
# ```
# 1. Click anywhere on canvas
# 2. Click the "+" button that appears
# 3. Search for node type (e.g., "Gmail")
# 4. Click to add it
# ```
#
# **Step 2: Connect Nodes**
# ```
# 1. Hover over the first node
# 2. Drag from the small circle on the right side
# 3. Drop it onto the next node
# 4. A line appears showing the connection
# ```
#
# **Step 3: Arrange Your Workflow**
# ```
# 1. Click and drag nodes to rearrange
# 2. Keep it organized (top-to-bottom or left-to-right)
# 3. Group related nodes together
# ```
#
# ### Pro Tips for the Canvas
#
# **Tip 1: Keep It Linear**
# - Organize nodes in a clear flow (top → bottom)
# - Avoid crossing connection lines if possible
#
# **Tip 2: Use Sticky Notes**
# - Add notes to explain complex sections
# - Right-click → "Add Sticky Note"
#
# **Tip 3: Name Your Nodes**
# - Rename nodes to describe what they do
# - "Send Welcome Email" is clearer than "Gmail"
#
# ---

# %% [markdown]
# ## 3. Node Editor - Where You Configure Each Step
#
# ### What Is the Node Editor?
#
# The **node editor** is the panel that opens when you click a node. This is where you **configure what that specific node does**.
#
# ### Real-Life Analogy
#
# Think of each node like a **kitchen appliance**:
#
# **Microwave example:**
# - You select the appliance (add Gmail node)
# - You set the parameters (time, power level)
# - You add ingredients (email content, recipient)
# - You press start (execute)
#
# The **node editor** is like the control panel on your microwave.
#
# ### What You See in the Node Editor
#
# When you click a node, a panel slides in from the right:
#  ```
# ┌─────────────────────────────────────────┐
# │ Gmail                              [×]  │
# ├─────────────────────────────────────────┤
# │                                         │
# │ 📋 Parameters                           │
# │                                         │
# │ Credential to connect with:             │
# │ [Select Credential ▼]                   │
# │                                         │
# │ ─────────────────────────────────       │
# │                                         │
# │ Resource: Send Email                    │
# │                                         │
# │ To:                                     │
# │ [sarah@email.com_____________]          │
# │                                         │
# │ Subject:                                │
# │ [Welcome to our course!______]          │
# │                                         │
# │ Email Type: Text ▼                      │
# │                                         │
# │ Message:                                │
# │ ┌─────────────────────────────────────┐ │
# │ │ Hi {{ $json.name }},                │ │
# │ │                                     │ │
# │ │ Welcome aboard!                     │ │
# │ └─────────────────────────────────────┘ │
# │                                         │
# │ ⚡ Add Option                            │
# │                                         │
# │              [Execute Node]             │
# └─────────────────────────────────────────┘
# ```
#
# ### Sections in the Node Editor
#
# **1. Node Name (Top)**
# - Shows which node you're editing
# - Click to rename the node
#
# **2. Credentials Section**
# - Select which account to use
# - Create new credentials if needed
#
# **3. Parameters Section**
# - Main settings for the node
# - Required fields marked with *
# - Optional fields can be expanded
#
# **4. Expression Mode**
# - Toggle between fixed values and dynamic expressions
# - Look for the `{{ }}` icon
#
# **5. Execute Node Button (Bottom)**
# - Test this single node
# - See results immediately
#
# ### How to Configure a Node
#
# **Example: Setting Up a Gmail Node**
#
# **Step 1: Select Credential**
# ```
# Click "Credential to connect with"
# → "Create New Credential"
# → Sign in to your Gmail
# → Authorize n8n
# → Credential saved ✓
# ```
#
# **Step 2: Fill Required Fields**
# ```
# To: sarah@email.com
# Subject: Welcome!
# Message: Hello and welcome to our course!
# ```
#
# **Step 3: Add Dynamic Data (Optional)**
# ```
# Click the "Expression" toggle next to "To" field
# Type: {{ $json.email }}
# Now it uses email from previous node
# ```
#
# **Step 4: Test It**
# ```
# Click "Execute Node" at bottom
# Check if email was sent
# ```
#
# ### Field Types You'll Encounter
#
# | Field Type | What It Is | Example |
# |------------|------------|---------|
# | **Text Input** | Simple text box | Email subject line |
# | **Dropdown** | Select from options | Choose resource type |
# | **Toggle** | On/Off switch | Enable/disable feature |
# | **Expression** | Dynamic values with {{ }} | {{ $json.name }} |
# | **JSON Editor** | For complex data | Custom API body |
# | **Date Picker** | Select date/time | Schedule for later |
#
# ### 💡 Common Node Editor Tricks
#
# **Trick 1: Expression Mode vs Fixed Mode**
# - **Fixed Mode**: You type exact value ("sarah@email.com")
# - **Expression Mode**: You reference data ({{ $json.email }})
# - Toggle between them with the `=` icon
#
# **Trick 2: See Available Data**
# - Click "Expression" mode
# - Click the variable icon
# - Browse all data from previous nodes
#
# **Trick 3: Copy Node Settings**
# - Right-click node → "Duplicate"
# - All settings are copied
# - Just change what's different
#
# ---

# %% [markdown]
# ## 4. Execution Log - Your Workflow History
#
# ### What Is the Execution Log?
#
# The **execution log** shows a **history of every time your workflow ran** — successful or failed.
#
# Think of it as a flight recorder for your automation.
#
# ### Real-Life Analogy
#
# Imagine a hospital's **patient log book**:
# - Records every patient who came in
# - Shows what treatment they received
# - Notes if treatment succeeded or had issues
# - Timestamps everything
#
# The execution log does this for your workflows.
#
# ### How to Access Execution Log
#
# **Option 1: From Main Menu**
# ```
# Click "Executions" in the left sidebar
# → See list of all past runs
# ```
#
# **Option 2: From Canvas**
# ```
# After running a workflow
# → Execution panel appears at bottom
# → Shows most recent runs
# ```
#
# ### What You See in Execution Log
#
# ```
# ┌─────────────────────────────────────────────────────┐
# │ Executions                           [Filter ▼]     │
# ├─────────────────────────────────────────────────────┤
# │                                                     │
# │ ✅ Feb 24, 2026 2:30 PM  Success  [View Details]    │
# │    New Customer Onboarding                          │
# │    Duration: 2.3s                                   │
# │                                                     │
# │ ❌ Feb 24, 2026 2:15 PM  Failed   [View Details]    │
# │    New Customer Onboarding                          │
# │    Error: Invalid email address                     │
# │                                                     │
# │ ✅ Feb 24, 2026 1:45 PM  Success  [View Details]    │
# │    New Customer Onboarding                          │
# │    Duration: 1.8s                                   │
# │                                                     │
# │ ✅ Feb 24, 2026 1:30 PM  Success  [View Details]    │
# │    New Customer Onboarding                          │
# │    Duration: 2.1s                                   │
# │                                                     │
# └─────────────────────────────────────────────────────┘
# ```
# ### Information in Each Execution Entry
#
# **1. Status Icon**
# - ✅ Green checkmark = Success
# - ❌ Red X = Failed
# - 🔄 Spinning = Currently running
# - ⏸️ Paused = Waiting for something
#
# **2. Timestamp**
# - When the workflow ran
# - Time zone based on your location
#
# **3. Workflow Name**
# - Which workflow was executed
#
# **4. Duration**
# - How long it took to complete
# - Useful for finding slow workflows
#
# **5. Error Message (if failed)**
# - What went wrong
# - Which node caused the issue
#
# ### Viewing Execution Details
#
# **Click "View Details" on any execution:**
#
# ```
# ┌─────────────────────────────────────────────────────┐
# │ Execution Details                              [×]  │
# ├─────────────────────────────────────────────────────┤
# │                                                     │
# │ Status: ✅ Success                                  │
# │ Started: Feb 24, 2026 2:30:15 PM                    │
# │ Finished: Feb 24, 2026 2:30:17 PM                   │
# │ Duration: 2.3 seconds                               │
# │                                                     │
# │ ─────────────────────────────────────               │
# │                                                     │
# │ ┌─────────────┐                                     │
# │ │   Webhook   │ ✅ 1 item                           │
# │ └──────┬──────┘                                     │
# │        │                                            │
# │        ↓                                            │
# │ ┌─────────────┐                                     │
# │ │    Gmail    │ ✅ 1 item                           │
# │ └──────┬──────┘                                     │
# │        │                                            │
# │        ↓                                            │
# │ ┌─────────────┐                                     │
# │ │    Slack    │ ✅ 1 item                           │
# │ └─────────────┘                                     │
# │                                                     │
# │ Click any node to see data that passed through      │
# └─────────────────────────────────────────────────────┘
# ```
#
# ### Why Execution Log Matters
#
# **1. Debugging Failed Workflows**
# - See exactly which node failed
# - Read error messages
# - Check what data was received
#
# **2. Verifying Success**
# - Confirm workflow ran as expected
# - See how many items were processed
# - Check actual data that was sent
#
# **3. Performance Monitoring**
# - Find slow nodes
# - Optimize workflow speed
# - Track execution frequency
#
# **4. Audit Trail**
# - Compliance requirements
# - Track automated actions
# - Prove workflow ran correctly
#
# ### Filtering Executions
#
# You can filter the log to find specific runs:
#
# **Filter by Status:**
# - Show only successful runs
# - Show only failed runs
# - Show only running executions
#
# **Filter by Date:**
# - Last 24 hours
# - Last 7 days
# - Custom date range
#
# **Search by Name:**
# - Find specific workflow executions
#
# ### Pro Tips for Using Execution Log
#
# **Tip 1: Always Check Failed Executions**
# - Don't ignore red X marks
# - Failed workflows might need immediate attention
# - Fix errors to prevent data loss
#
# **Tip 2: Monitor Execution Frequency**
# - If workflow runs too often → adjust trigger
# - If workflow doesn't run → check trigger settings
#
# **Tip 3: Use for Debugging**
# - Click through each node in failed execution
# - Compare data between successful and failed runs
# - Look for patterns in errors
#
# ---

# %% [markdown]
# ## 5. Testing - Making Sure Everything Works
#
# ### What Is Testing in n8n?
#
# **Testing** is running your workflow (or individual nodes) to see if they work correctly **before going live**.
#
# Think of it as a **dress rehearsal** before the real performance.
#
# ### Real-Life Analogy
#
# Before a play opens:
# - Actors do dress rehearsals
# - They test lights, sound, props
# - Fix any issues before opening night
# - Opening night = workflow going live
#
# Testing prevents embarrassing mistakes in front of your audience (customers).
#
# ### Types of Testing in n8n
#
# **1. Test Single Node**
# - Execute just one node
# - See its output immediately
# - Doesn't run the whole workflow
#
# **2. Test Entire Workflow**
# - Execute from trigger to end
# - See how data flows through all nodes
# - Complete end-to-end test
#
# **3. Test with Manual Data**
# - Use fake/sample data
# - Don't trigger real actions yet
# - Safe for testing
#
# ### How to Test a Single Node
#
# **Step-by-Step:**
#
# ```
# 1. Click the node you want to test
#
# 2. Configure its parameters
#
# 3. Click "Execute Node" button (bottom of node editor)
#
# 4. Wait for execution (usually 1-3 seconds)
#
# 5. Green checkmark ✅ appears if successful
#
# 6. Click node to see output data
# ```
#
# **Example: Testing Gmail Node**
#
# ```
# Before clicking "Execute Node":
# - Set recipient email
# - Write subject and message
# - Make sure credentials are connected
#
# After clicking "Execute Node":
# - Email is actually sent (be careful!)
# - Node shows ✅ if successful
# - Click to see server response
# ```
#
# ### How to Test Entire Workflow
#
# **Method 1: Manual Trigger**
#
# ```
# 1. Add "Manual Trigger" node at start
#
# 2. Connect your workflow
#
# 3. Click "Execute Workflow" button (top right)
#
# 4. Watch each node execute one by one
#
# 5. Check results
# ```
#
# **Method 2: Test Button on Trigger Nodes**
#
# ```
# Some triggers have a "Listen for Test Event" button
#
# Example with Webhook:
# 1. Click "Listen for Test Event"
# 2. Send test data to webhook URL
# 3. Workflow executes with test data
# 4. See results
# ```
#
# ### Understanding Test Results
#
# When you test, each node shows a status:
#
# ```
# ┌─────────────┐
# │   Gmail     │ ✅ Success - 1 item processed
# └─────────────┘
#
# ┌─────────────┐
# │   Slack     │ ⏱️ Running...
# └─────────────┘
#
# ┌─────────────┐
# │  HTTP Req   │ ❌ Failed - Connection timeout
# └─────────────┘
# ```
#
# **Click any node to see:**
# - Input data (what it received)
# - Output data (what it produced)
# - Execution time
# - Any error messages
#
# ### Testing Best Practices
#
# **✅ DO:**
#
# **1. Test with Fake Data First**
# ```
# Don't test with real customer emails
# Use your own email address
# Use test accounts when available
# ```
#
# **2. Test Each Node Individually**
# ```
# Before connecting everything
# Test one node at a time
# Confirm each works independently
# ```
#
# **3. Test Edge Cases**
# ```
# What if email field is empty?
# What if name has special characters?
# What if number is negative?
# ```
#
# **4. Test Error Scenarios**
# ```
# What happens if API fails?
# What if credential expires?
# Add error handling nodes
# ```
#
# **❌ DON'T:**
#
# **1. Test in Production**
# ```
# Don't test with real customers
# Don't send actual emails during test
# Don't charge real credit cards
# ```
#
# **2. Skip Testing**
# ```
# "It'll probably work" ← Famous last words
# Always test before activating
# ```
#
# **3. Test Only Happy Path**
# ```
# Also test what happens when things go wrong
# ```
#
# ### Example Testing Workflow
#
# **Scenario: New Customer Onboarding**
#
# **Step 1: Test with Your Own Email**
# ```
# Webhook → receives test data
# Gmail → sends to YOUR email (not customer)
# Slack → posts to TEST channel
# Google Sheets → writes to TEST sheet
# ```
#
# **Step 2: Verify Each Output**
# ```
# ✅ Did you receive the email?
# ✅ Is the Slack message correct?
# ✅ Is data in spreadsheet accurate?
# ```
#
# **Step 3: Test Edge Cases**
# ```
# ❓ What if name field is empty?
# ❓ What if email is invalid?
# ❓ What if webhook receives bad data?
# ```
#
# **Step 4: Add Error Handling**
# ```
# IF node → check if email is valid
# Set node → provide default values
# Stop and Error node → halt if critical failure
# ```
#
# **Step 5: Final Test**
# ```
# Run entire workflow start to finish
# Confirm all outputs are correct
# Now you're ready to go live!
# ```
#
# ---

# %% [markdown]
# ## 6. Debug Panel - Finding and Fixing Problems
#
# ### What Is the Debug Panel?
#
# The **debug panel** is where you see **detailed information** about what happened during execution — especially useful when something goes wrong.
#
# ### Real-Life Analogy
#
# Think of it like a **medical diagnosis**:
# - Patient (workflow) has symptoms (errors)
# - Doctor (you) orders tests (debug panel)
# - Lab results (execution details) reveal the problem
# - Treatment (fix) can begin
#
# ### Where to Find Debug Information
#
# **Option 1: Click on a Node After Execution**
#
# ```
# After running workflow:
# 1. Click any node
# 2. See "Input" and "Output" tabs
# 3. View JSON data that passed through
# ```
#
# **Option 2: Execution Details View**
#
# ```
# Open execution from log
# Click individual nodes
# See step-by-step data flow
# ```
#
# ### What the Debug Panel Shows
#
#
# ```
# ┌─────────────────────────────────────────────────────┐
# │ Gmail Node                                          │
# ├─────────────────────────────────────────────────────┤
# │                                                     │
# │ [Input] [Output] [Code]                             │
# │                                                     │
# │ ── OUTPUT ──                                        │
# │                                                     │
# │ ✅ 1 item                                           │
# │                                                     │
# │ {                                                   │
# │   "messageId": "abc123xyz789",                      │
# │   "labelIds": ["SENT"],                             │
# │   "threadId": "thread456"                           │
# │ }                                                   │
# │                                                     │
# │ Execution Time: 1.2 seconds                         │
# │                                                     │
# └─────────────────────────────────────────────────────┘
# ```
#
# ### Key Debugging Features
#
# **1. Input Tab**
# - Shows data the node **received**
# - Helps verify data flow from previous node
# - Troubleshoot missing fields
#
# **Example:**
# ```json
# Input from Webhook:
# {
#   "name": "Sarah",
#   "email": "sarah@email.com",
#   "message": "I need help"
# }
# ```
#
# **2. Output Tab**
# - Shows data the node **produced**
# - What gets passed to next node
# - Check if transformation worked correctly
#
# **Example:**
# ```json
# Output from Gmail:
# {
#   "messageId": "12345",
#   "status": "sent",
#   "to": "sarah@email.com"
# }
# ```
#
# **3. JSON/Table View Toggle**
# - **JSON**: Raw data format
# - **Table**: Human-readable rows and columns
# - Switch based on preference
#
# **4. Binary Data**
# - For files, images, PDFs
# - Download to inspect
# - See file size and type
#
# ### Common Debugging Scenarios
#
# **Scenario 1: "Node Received Empty Data"**
#
# ```
# Problem: Next node has no data to process
#
# Debug Steps:
# 1. Click the PREVIOUS node
# 2. Check its Output tab
# 3. Is data actually there?
# 4. Are nodes connected properly?
#
# Common Causes:
# - Previous node filtered out all items
# - Wrong field name in expression
# - Node isn't connected
# ```
#
# **Scenario 2: "Expression Error"**
#
# ```
# Problem: {{ $json.email }} shows as "undefined"
#
# Debug Steps:
# 1. Click node with error
# 2. Check Input tab
# 3. Look at actual field names
#
# Fix:
# If you see { "userEmail": "..." }
# Use {{ $json.userEmail }} instead of {{ $json.email }}
# ```
#
# **Scenario 3: "API Request Failed"**
#
# ```
# Problem: HTTP Request node returns error
#
# Debug Steps:
# 1. Check Output tab for error message
# 2. Look at status code (404, 500, 401, etc.)
# 3. Check Input tab for request body
#
# Common Errors:
# - 401: Bad credentials
# - 404: Wrong URL
# - 500: Server error (try again)
# - Timeout: API too slow
# ```
#
# **Scenario 4: "Wrong Data Type"**
#
# ```
# Problem: Node expects number, receives text
#
# Debug Steps:
# 1. Check Input data type
# 2. Use Function node to convert
# 3. Example: parseInt({{ $json.age }})
#
# Before: { "age": "25" } ← Text
# After: { "age": 25 } ← Number
# ```
#
# ### Advanced Debug Techniques
#
# **1. Add Set Nodes for Debugging**
#
# ```
# Insert "Set" nodes between steps:
# - Set test values manually
# - See if downstream nodes work
# - Isolate the problem area
# ```
#
# **2. Use Function Nodes to Log**
#
# ```javascript
# // In Function node
# console.log('Debug: Email is', $input.all()[0].json.email);
# return $input.all();
# ```
#
# Check execution log for console output.
#
# **3. Split Complex Workflows**
#
# ```
# If big workflow fails:
# 1. Disable half the nodes
# 2. Test the first half
# 3. Does it work?
# 4. Re-enable and test second half
# 5. Binary search for problem!
# ```
#
# **4. Check Execution Time**
#
# ```
# Slow execution times indicate:
# - API rate limiting
# - Large data processing
# - Network issues
# - Inefficient nodes
# ```
#
# ### Debug Panel Pro Tips
#
# **Tip 1: Use JSON View for Exact Field Names**
# ```
# You think field is "email"
# JSON shows it's actually "userEmail"
# Copy exact field name
# No more typos!
# ```
#
# **Tip 2: Compare Successful vs Failed Executions**
# ```
# Open a successful execution
# Open a failed execution
# Compare the Input data
# Spot the difference
# ```
#
# **Tip 3: Enable "Save Execution Data"**
# ```
# Settings → Save successful executions
# Now you can debug even successes
# See what data actually went through
# ```
#
# **Tip 4: Use Browser DevTools**
# ```
# Press F12 in browser
# Go to Network tab
# See actual HTTP requests n8n makes
# Advanced debugging for API issues
# ```
#
# ---

# %% [markdown]
# ## 7. How All UI Components Work Together
#
# ### Complete Workflow Creation Process
#
# Let's see how you use all UI components together:
#
# **Step 1: Design on Canvas**
# ```
# Canvas:
# - Add trigger node
# - Add action nodes
# - Connect them with lines
# - Arrange logically
# ```
#
# **Step 2: Configure Each Node**
# ```
# Node Editor:
# - Click each node
# - Set credentials
# - Fill parameters
# - Add expressions
# ```
#
# **Step 3: Test Your Work**
# ```
# Testing:
# - Execute single nodes first
# - Then test entire workflow
# - Use fake data initially
# ```
#
# **Step 4: Debug Issues**
# ```
# Debug Panel:
# - Check Input/Output tabs
# - Read error messages
# - Verify data flow
# - Fix problems
# ```
#
# **Step 5: Monitor After Activation**
# ```
# Execution Log:
# - Watch for failures
# - Track performance
# - Audit successful runs
# ```
#
# ### Real-World Example: Building "New Sale Alert"
#
# **Goal:** When Stripe charges customer, send Slack notification
#
# **Using Each UI Component:**
#
# **1. Canvas Work:**
# ```
# Add Stripe Webhook trigger
# Add Slack Send Message node
# Connect them with line
# ```
#
# **2. Node Editor Work:**
# ```
# Stripe Webhook:
# - Copy webhook URL
# - Set up in Stripe dashboard
#
# Slack Node:
# - Add Slack credentials
# - Select channel: #sales
# - Message: "New sale: ${{ $json.amount }}"
# ```
#
# **3. Testing:**
# ```
# Use Stripe test mode
# Trigger test payment
# Check Slack receives message
# ```
#
# **4. Debugging (if needed):**
# ```
# Message not appearing?
# → Check Debug Panel
# → Input tab: Is amount field present?
# → Output tab: Did Slack API respond?
# → Fix: Amount field is actually "total"
# → Update expression: ${{ $json.total }}
# ```
#
# **5. Monitor Execution Log:**
# ```
# After going live:
# Check daily for failed executions
# Ensure all sales trigger alerts
# Fix any credential expiration issues
# ```
#
# ---

# %% [markdown]
# ## 8. Common UI Mistakes & How to Avoid Them
#
# ### ❌ Mistake 1: Not Saving Workflows
#
# **Problem:** You build entire workflow, close browser, everything gone
#
# **Solution:**
# - Workflows auto-save when you activate them
# - Name your workflow properly
# - Check "Workflows" sidebar to confirm it's saved
#
# ---
#
# ### ❌ Mistake 2: Losing Track of What Each Node Does
#
# **Problem:** You have 20 "HTTP Request" nodes, can't tell them apart
#
# **Solution:**
# - Rename every node descriptively
# - "Get Customer Data" instead of "HTTP Request"
# - Use sticky notes to label sections
#
# ---
#
# ### ❌ Mistake 3: Not Checking Execution Log
#
# **Problem:** Workflow silently failing for weeks, you don't notice
#
# **Solution:**
# - Check execution log daily (at first)
# - Set up error notifications
# - Use Error Trigger node to alert you
#
# ---
#
# ### ❌ Mistake 4: Testing with Real Data Too Soon
#
# **Problem:** Accidentally send 100 emails to real customers during test
#
# **Solution:**
# - ALWAYS use test credentials first
# - Send test emails to yourself
# - Use "Manual Trigger" for controlled testing
#
# ---
#
# ### ❌ Mistake 5: Ignoring Debug Panel
#
# **Problem:** "It doesn't work" but you don't know why
#
# **Solution:**
# - Click nodes after execution
# - Read the Output tab
# - Error messages tell you exactly what's wrong
#
# ---

# %% [markdown]
# ## 9. Quick UI Navigation Shortcuts
#
# ### Keyboard Shortcuts (Time Savers!)
#
# | Shortcut | What It Does |
# |----------|--------------|
# | **Ctrl/Cmd + S** | Save workflow |
# | **Ctrl/Cmd + Enter** | Execute workflow |
# | **Delete** | Delete selected node |
# | **Ctrl/Cmd + C** | Copy selected node |
# | **Ctrl/Cmd + V** | Paste node |
# | **Ctrl/Cmd + Z** | Undo |
# | **Ctrl/Cmd + D** | Duplicate node |
# | **+** | Add new node |
# | **Space + Drag** | Pan canvas |
#
# ### Mouse Shortcuts
#
# | Action | Result |
# |--------|--------|
# | **Click + Drag on canvas** | Pan/move view |
# | **Scroll wheel** | Zoom in/out |
# | **Drag from node output** | Create connection |
# | **Double-click node** | Open node editor |
# | **Right-click node** | Context menu |
#
# ---
